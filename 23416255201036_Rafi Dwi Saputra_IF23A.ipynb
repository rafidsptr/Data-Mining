# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Memuat data iris
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

#Menggunakan DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
df['cluster'] = dbscan.fit_predict(df)

#Menampilkan jumlah kluster yang dihasilkan (klaster -1 menandakan noise)
print("Jumlah klaster: ", df ['cluster'].nunique())
#Visualisasi pengelompokan menggunakan scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', hue='cluster', data=df, palette='viridis', s=100)
plt.title("DBSCAN Clustering on Iris Dataset")
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend()
plt.show()
# Out:
# Jumlah klaster:  3

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score

#Menghitung Silhouette Score
silhouette_avg = silhouette_score(df.iloc[:, :-1], df['cluster'])
print(f'Silhouette Score for DBSCAN: {silhouette_avg}')

#Menghitung Davies_Bouldin Index (semakin rendah, semakin baik)
db_index = davies_bouldin_score(df.iloc[:, :-1], df['cluster'])
print(f'Davies-Bouldin Index for DBSCAN: {db_index}')
# Out:
# Silhouette Score for DBSCAN: 0.48603419703456857
# Davies-Bouldin Index for DBSCAN: 7.222448016359581

# %%
#Visualisasi pengelompokan menggunakan scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(x='sepal length (cm)', y='sepal width (cm)', hue='cluster', data=df, palette='viridis', s=100)
plt.title("DBSCAN Clustering on Iris Dataset")
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend()
plt.show()
